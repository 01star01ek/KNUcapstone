# %% [markdown]
# ### pytorch YOLO링크
# - https://github.com/ultralytics/yolov5 repository부터 clone
#
# <코드>
# ```linux
# git clone https://github.com/ultralytics/yolov5  # clone
# cd yolov5
# pip install -r requirements.txt  # install
# ```

# %% [markdown]
# ### 학습방법
#
# 1. 학습 방식
# - data.yaml : 자모음과 경로등 정보 저장된 파일
#
# <코드>
# ```python
# python train.py --img 416 --batch 16 --epochs 3 --data "dataset/data.yaml" --weights yolov5s.pt --cache
# ```

# %% [markdown]
# ### 적용방법
#
# <코드>
# ```python
# !python detect.py --weights "모델.pt" --source "사진.jpg" # 이미지 수아번역
# !python detect.py --weights "모델.pt" --source "영상.avi" # 영상   수아번역
# ```

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.11.0 torch-2.3.0+cu121 CPU
# Setup complete ✅ (8 CPUs, 62.7 GB RAM, 633.4/874.9 GB disk)

# %%
# !python detect.py --weights "./runs/train/exp/weights/best.pt" --source "./dataset/test/images/ㄱ_1_42.jpg"
# Out:
# /home/toc3/anaconda3/envs/py3_11/lib/python3.11/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /home/toc3/anaconda3/envs/py3_11/lib/python3.11/site-packages/torch/cuda/__init__.py:749: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() if nvml_count < 0 else nvml_count
# ...

# %%
# !python detect.py --weights "./runs/train/exp/weights/best.pt" --source "../SignLanguagedataset/output_video/ㄱ/ㄱ_1.avi"
# Out:
# /home/toc3/anaconda3/envs/py3_11/lib/python3.11/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /home/toc3/anaconda3/envs/py3_11/lib/python3.11/site-packages/torch/cuda/__init__.py:749: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() if nvml_count < 0 else nvml_count
# ...
